# %% [markdown]
# <a href="https://colab.research.google.com/github/aishwaryajnaik/DSA-Programs/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error, confusion_matrix
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn import linear_model
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from xgboost import XGBRegressor

# %%
data1 = pd.read_csv('/content/ICRISAT-District Level Data PREV. YIELD DATA.csv')
data1.head()
# Out:
#    Dist Code  Year  State Code State Name  Dist Name  RICE AREA (1000 ha)  \
# 0         64  1966           5  Karnataka  Bangalore                 45.0
# 1         64  1967           5  Karnataka  Bangalore                 36.0
# 2         64  1968           5  Karnataka  Bangalore                 35.3
# 3         64  1969           5  Karnataka  Bangalore                 37.3
# 4         64  1970           5  Karnataka  Bangalore                 43.5
#
#    RICE PRODUCTION (1000 tons)  RICE YIELD (Kg per ha)
# 0                         65.0                 1444.44
# 1                         21.0                  583.33
# 2                         43.0                 1218.13
# 3                         41.4                 1109.92
# 4                         63.7                 1464.37

# %%
data2 = pd.read_csv('/content/ICRISAT-District Level Data RAINFALL.csv')
data2.head()
# Out:
#    Dist Code              Year  State Code State Name  Dist Name  \
# 0         64  Average 30 years           5  Karnataka  Bangalore
# 1         65  Average 30 years           5  Karnataka      Kolar
# 2         66  Average 30 years           5  Karnataka     Tumkur
# 3         67  Average 30 years           5  Karnataka     Mysore
# 4         68  Average 30 years           5  Karnataka     Mandya
#
#    JANUARY NORMAL RAINFALL (Millimeters)  \
# 0                                      3
# 1                                     10
# 2                                      6
# 3                                      4
# 4                                      4
#
#    FEBRUARY NORMAL RAINFALL (Millimeters)  \
# 0                                      10
# 1                                       9
# 2                                       3
# 3                                      10
# 4                                       5
#
# ...

# %%
data3 = pd.read_csv('/content/ICRISAT-District Level Data TEMPERATURE.csv')
data3.head()
# Out:
#    Dist Code  Year  State Code State Name Dist Name  \
# 0         65  2009           5  Karnataka     Kolar
# 1         65  2010           5  Karnataka     Kolar
# 2         65  2011           5  Karnataka     Kolar
# 3         65  2012           5  Karnataka     Kolar
# 4         65  2013           5  Karnataka     Kolar
#
#    JANUARY ACTUAL (Millimeters)  FEBRUARY ACTUAL (Millimeters)  \
# 0                         18.80                           9.02
# 1                          5.36                           3.62
# 2                          4.43                          19.54
# 3                          7.12                           4.18
# 4                          0.56                           4.19
#
#    MARCH ACTUAL (Millimeters)  APRIL ACTUAL (Millimeters)  \
# 0                       11.96                       25.28
# 1                        4.35                       46.57
# 2                        2.01                       58.29
# ...
